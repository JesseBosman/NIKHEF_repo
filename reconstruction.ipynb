# %%
import tensorflow as tf
import pandas as pd
import numpy as np
from sklearn.ensemble import RandomForestClassifier as RFC
from sklearn.metrics import accuracy_score, confusion_matrix, precision_score, recall_score, ConfusionMatrixDisplay
from sklearn.model_selection import RandomizedSearchCV, train_test_split
from scipy.stats import randint
import matplotlib.pyplot as plt
import seaborn as sns
from collections import Counter
import os

from functions import *
# Out:
# 2024-05-23 14:25:04.112940: I tensorflow/core/platform/cpu_feature_guard.cc:210] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2024-05-23 14:25:05.144784: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT

# %%
neutr_paths = os.listdir("datav2")
muon_path = "datav2/"+neutr_paths.pop(-2)

for i, path in enumerate(neutr_paths):
    neutr_paths[i] = "datav2/"+path
neutr_types = ["neutrino_elec-CC","neutrino_muon-NC","neutrino_tau-CC","neutrino_anti-elec-CC","neutrino_anti-muon-CC","neutrino_anti-tau-CC","neutrino_muon-CC","neutrino_anti-muon-NC"]




df_muon = load_muon_data(muon_path)
df_neutr = load_neutrino_data(neutr_paths, neutr_types)

# %%
df = pd.concat([df_muon, df_neutr], ignore_index=True)
df['jmuon_E'].hist(bins='auto', alpha = 0.5, label = 'reco' )
plt.legend()
plt.xlim(0, 10000)
plt.show()
df['energy'].hist(bins='auto', alpha = 0.5, label = "true")
plt.legend()
plt.xlim(0, 10000)
plt.show()
# plt.legend()
# plt.xlim(0, 10000)
# plt.title("Reconstructed energy vs true energy distributions")
# plt.show()

# %%
df['jmuon_E'].hist(bins=10000, alpha = 0.5, label = 'reco' )
df['energy'].hist(bins=10000, alpha = 0.5, label = "true")
plt.legend()
plt.xlim(0, 10000)
plt.title("Reconstructed energy vs true energy distributions")
plt.show()
